# %%
import pandas as pd

# %%
new_df = pd.read_csv('data/ZIP-COUNTY-FIPS_2010-03.csv', encoding='UTF-8')
new_df
# Out:
#          ZIP         COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003     Autauga County    AL        1001      H1
# 1      36006     Autauga County    AL        1001      H1
# 2      36008     Autauga County    AL        1001      H1
# 3      36022     Autauga County    AL        1001      H1
# 4      36051     Autauga County    AL        1001      H1
# ...      ...                ...   ...         ...     ...
# 46850    820   St. Croix Island    VI       78010      H4
# 46851    840   St. Croix Island    VI       78010      H4
# 46852    850   St. Croix Island    VI       78010      H4
# 46853    830    St. John Island    VI       78020      H4
# 46854    802  St. Thomas Island    VI       78030      H4
#
# [46855 rows x 5 columns]

# %%
new_df = new_df.rename(columns={"ZIP": "Zip"})
new_df
# Out:
#          Zip         COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0      36003     Autauga County    AL        1001      H1
# 1      36006     Autauga County    AL        1001      H1
# 2      36008     Autauga County    AL        1001      H1
# 3      36022     Autauga County    AL        1001      H1
# 4      36051     Autauga County    AL        1001      H1
# ...      ...                ...   ...         ...     ...
# 46850    820   St. Croix Island    VI       78010      H4
# 46851    840   St. Croix Island    VI       78010      H4
# 46852    850   St. Croix Island    VI       78010      H4
# 46853    830    St. John Island    VI       78020      H4
# 46854    802  St. Thomas Island    VI       78030      H4
#
# [46855 rows x 5 columns]

# %%
new_df1 = pd.read_csv('data/zip-lat-lng.csv', encoding='UTF-8')
new_df1
# Out:
#          Zip        City State   Latitude   Longitude  Timezone  \
# 0      67553  Liebenthal    KS  38.654948  -99.320620        -6
# 1      85743      Tucson    AZ  32.335122 -111.148880        -7
# 2      75016      Irving    TX  32.767268  -96.777626        -6
# 3      60401     Beecher    IL  41.350484  -87.624080        -6
# 4      80432        Como    CO  39.243440 -105.794310        -7
# ...      ...         ...   ...        ...         ...       ...
# 43186  88540     El Paso    TX  31.694842 -106.299987        -7
# 43187  98345     Keyport    WA  47.702342 -122.625540        -8
# 43188  99361   Waitsburg    WA  46.209202 -118.158840        -8
# 43189   8821    Flagtown    NJ  40.518578  -74.685450        -5
# 43190   4736     Caribou    ME  46.878869  -68.011280        -5
#
#        Daylight savings time flag               geopoint
# 0                               1    38.654948,-99.32062
# 1                               0   32.335122,-111.14888
# ...

# %%
new_df=new_df.merge(new_df1, on='Zip', how='left')
new_df
# Out:
#          Zip         COUNTYNAME STATE  STCOUNTYFP CLASSFP           City  \
# 0      36003     Autauga County    AL        1001      H1   Autaugaville
# 1      36006     Autauga County    AL        1001      H1    Billingsley
# 2      36008     Autauga County    AL        1001      H1          Booth
# 3      36022     Autauga County    AL        1001      H1     Deatsville
# 4      36051     Autauga County    AL        1001      H1        Marbury
# ...      ...                ...   ...         ...     ...            ...
# 46850    820   St. Croix Island    VI       78010      H4  Christiansted
# 46851    840   St. Croix Island    VI       78010      H4   Frederiksted
# 46852    850   St. Croix Island    VI       78010      H4      Kingshill
# 46853    830    St. John Island    VI       78020      H4        St John
# 46854    802  St. Thomas Island    VI       78030      H4      St Thomas
#
#       State   Latitude  Longitude  Timezone  Daylight savings time flag  \
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46855 entries, 0 to 46854
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Zip                         46855 non-null  int64
#  1   COUNTYNAME                  46855 non-null  object
#  2   STATE                       46855 non-null  object
#  3   STCOUNTYFP                  46855 non-null  int64
#  4   CLASSFP                     46855 non-null  object
#  5   City                        46517 non-null  object
#  6   State                       46517 non-null  object
#  7   Latitude                    46517 non-null  float64
#  8   Longitude                   46517 non-null  float64
#  9   Timezone                    46517 non-null  float64
#  10  Daylight savings time flag  46517 non-null  float64
#  11  geopoint                    46517 non-null  object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 4.6+ MB

# %%
new_df3 = pd.read_csv('data/raw_new.csv', encoding='UTF-8')
new_df3
# Out:
#            _id        geoid  year  in100  msaid15                  msaname15  \
# 0            1   1001020100  2010    0.0  33860.0  Montgomery, AL Metro Area
# 1            2   1001020100  2015    0.0  33860.0  Montgomery, AL Metro Area
# 2            3   1001020200  2010    0.0  33860.0  Montgomery, AL Metro Area
# 3            4   1001020200  2015    0.0  33860.0  Montgomery, AL Metro Area
# 4            5   1001020300  2010    0.0  33860.0  Montgomery, AL Metro Area
# ...        ...          ...   ...    ...      ...                        ...
# 146107  146108  56043000302  2015    NaN      NaN                        NaN
# 146108  146109  56045951100  2010    NaN      NaN                        NaN
# 146109  146110  56045951100  2015    NaN      NaN                        NaN
# 146110  146111  56045951300  2010    NaN      NaN                        NaN
# 146111  146112  56045951300  2015    NaN      NaN                        NaN
#
# ...

# %%
new_df3 = new_df.rename(columns={"countyfips": "STCOUNTYFP"})
new_df3
# Out:
#          Zip         COUNTYNAME STATE  STCOUNTYFP CLASSFP           City  \
# 0      36003     Autauga County    AL        1001      H1   Autaugaville
# 1      36006     Autauga County    AL        1001      H1    Billingsley
# 2      36008     Autauga County    AL        1001      H1          Booth
# 3      36022     Autauga County    AL        1001      H1     Deatsville
# 4      36051     Autauga County    AL        1001      H1        Marbury
# ...      ...                ...   ...         ...     ...            ...
# 46850    820   St. Croix Island    VI       78010      H4  Christiansted
# 46851    840   St. Croix Island    VI       78010      H4   Frederiksted
# 46852    850   St. Croix Island    VI       78010      H4      Kingshill
# 46853    830    St. John Island    VI       78020      H4        St John
# 46854    802  St. Thomas Island    VI       78030      H4      St Thomas
#
#       State   Latitude  Longitude  Timezone  Daylight savings time flag  \
# ...

# %%
new_df3=new_df.merge(new_df, on='STCOUNTYFP', how='left')
new_df3
# Out:
#          Zip_x       COUNTYNAME_x STATE_x  STCOUNTYFP CLASSFP_x        City_x  \
# 0        36003     Autauga County      AL        1001        H1  Autaugaville
# 1        36003     Autauga County      AL        1001        H1  Autaugaville
# 2        36003     Autauga County      AL        1001        H1  Autaugaville
# 3        36003     Autauga County      AL        1001        H1  Autaugaville
# 4        36003     Autauga County      AL        1001        H1  Autaugaville
# ...        ...                ...     ...         ...       ...           ...
# 1478354    850   St. Croix Island      VI       78010        H4     Kingshill
# 1478355    850   St. Croix Island      VI       78010        H4     Kingshill
# 1478356    850   St. Croix Island      VI       78010        H4     Kingshill
# 1478357    830    St. John Island      VI       78020        H4       St John
# 1478358    802  St. Thomas Island      VI       78030        H4     St Thomas
#
# ...

# %%
new_df.to_csv('data/newcoi.csv', index = False, encoding = 'UTF-8')
